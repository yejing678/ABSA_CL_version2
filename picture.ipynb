# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5), dpi=200)
shift_stage_epoch = ['0', '1', '2', '3', '4', '5', '6', '7']
baseline_acc = [83.75]*8
baseline_f1 = [74.79]*8
laptop_accuracy = [83.75, 83.96, 84.49, 84.17, 85.06, 85.09, 84.7, 84.4]
laptop_f1 = [74.79, 74.21, 75.82, 75.88, 77.18, 77.19, 76.69, 76.6]
plt.plot(shift_stage_epoch, laptop_accuracy, c='purple', label="restaurant acc")
plt.plot(shift_stage_epoch, laptop_f1, c='purple', linestyle='--', label="restaurant f1")
plt.scatter(shift_stage_epoch, laptop_accuracy, c='purple', marker='*')
plt.scatter(shift_stage_epoch, laptop_f1, c='purple', marker='*')
plt.plot(shift_stage_epoch, baseline_acc, c='black', linestyle=':', label="baseline acc")
plt.plot(shift_stage_epoch, baseline_f1, c='black', linestyle='-.', label="baseline f1")
# plt.scatter(shift_stage_epoch, baseline_acc, c='black', marker='o')
# plt.scatter(shift_stage_epoch, baseline_f1, c='black', marker='o')
plt.legend(loc='best')
plt.yticks(range(70, 85, 5))
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel("Curriculum stage N", fontdict={'size': 12})
plt.ylabel("Accuarcy / F1 (%)", fontdict={'size': 12})
plt.title("BERT-SPC Restaurant-14")  # 添加标题

# 添加数值标签
for i, acc in enumerate(laptop_accuracy):
    plt.text(shift_stage_epoch[i], acc, str(acc), ha='center', va='bottom', fontsize=8)

for i, f1 in enumerate(laptop_f1):
    plt.text(shift_stage_epoch[i], f1, str(f1), ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.savefig("plot.png", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5), dpi=200)
shift_stage_epoch = ['0', '1', '2', '3', '4', '5', '6', '7']
baseline_acc = [76.91]*8
baseline_f1 = [71.71]*8
laptop_accuracy = [76.91, 76.53, 77.33, 77.27, 77.95, 78.01, 77.22, 77.43]
laptop_f1 = [71.71, 70.98, 72.45, 72.1, 73.68, 73.52, 72.42, 72.86]
plt.plot(shift_stage_epoch, laptop_accuracy, c='green', label="laptop acc")
plt.plot(shift_stage_epoch, laptop_f1, c='green', linestyle='--', label="laptop f1")
plt.scatter(shift_stage_epoch, laptop_accuracy, c='green', marker='^')
plt.scatter(shift_stage_epoch, laptop_f1, c='green', marker='^')
plt.plot(shift_stage_epoch, baseline_acc, c='black', linestyle=':', label="baseline acc")
plt.plot(shift_stage_epoch, baseline_f1, c='black', linestyle='-.', label="baseline f1")
# plt.scatter(shift_stage_epoch, baseline_acc, c='black', marker='o')
# plt.scatter(shift_stage_epoch, baseline_f1, c='black', marker='o')
plt.legend(loc='best')
plt.yticks(range(65, 80, 5))
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel("Curriculum stage N", fontdict={'size': 12})
plt.ylabel("Accuarcy / F1 (%)", fontdict={'size': 12})
plt.title("BERT-SPC Laptop-14")  # 添加标题

# 添加数值标签
for i, acc in enumerate(laptop_accuracy):
    plt.text(shift_stage_epoch[i], acc, str(acc), ha='center', va='bottom', fontsize=8)

for i, f1 in enumerate(laptop_f1):
    plt.text(shift_stage_epoch[i], f1, str(f1), ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.savefig("plot.png", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5), dpi=200)
shift_stage_epoch = ['0', '1', '2', '3', '4', '5', '6', '7']
baseline_acc = [76.91]*8
baseline_f1 = [71.71]*8
laptop_accuracy = [76.91, 76.53, 77.33, 77.27, 77.95, 78.01, 77.22, 77.43]
laptop_f1 = [71.71, 70.98, 72.45, 72.1, 73.68, 73.52, 72.42, 72.86]
plt.plot(shift_stage_epoch, laptop_accuracy, c='green', label="laptop acc")
plt.plot(shift_stage_epoch, laptop_f1, c='green', linestyle='--', label="laptop f1")
plt.scatter(shift_stage_epoch, laptop_accuracy, c='green', marker='^')
plt.scatter(shift_stage_epoch, laptop_f1, c='green', marker='^')
plt.plot(shift_stage_epoch, baseline_acc, c='black', linestyle=':', label="baseline acc")
plt.plot(shift_stage_epoch, baseline_f1, c='black', linestyle='-.', label="baseline f1")
# plt.scatter(shift_stage_epoch, baseline_acc, c='black', marker='o')
# plt.scatter(shift_stage_epoch, baseline_f1, c='black', marker='o')
plt.legend(loc='best')
plt.yticks(range(65, 80, 5))
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel("Curriculum stage N", fontdict={'size': 16})
plt.title("BERT-SPC Laptop-14")  # 添加标题

plt.tight_layout()  # 自动调整图像布局，包括坐标轴
plt.savefig("plot.png", bbox_inches='tight')  # 保存图像，并包含坐标轴

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5), dpi=100)
shift_stage_epoch = ['0','1', '2', '3', '4', '5','6','7']
baseline_acc = [76.91]*8
baseline_f1 = [71.71]*8
laptop_accuracy = [76.91, 76.53, 77.33, 77.27, 77.95, 78.01, 77.22, 77.43]
laptop_f1 = [71.71, 70.98, 72,45, 72.1, 73.68, 73.52, 72.42, 72.86]
# restaurant_acc = [84.335, 84.42, 84.51, 83.93, 85.3]
# restaurant_f1 = [76.03, 76.615, 76.36, 75.855, 78.25]
plt.plot(shift_stage_epoch, laptop_accuracy, c='green', label="laptop acc")
plt.plot(shift_stage_epoch, laptop_f1, c='green', linestyle='--', label="laptop f1")
# plt.plot(shift_stage_epoch, restaurant_acc, c='black', ls='-.', label="restaurant acc")
# plt.plot(shift_stage_epoch, restaurant_f1, c='black', linestyle=':', label="restaurant f1")
plt.scatter(shift_stage_epoch, laptop_accuracy, c='green', marker='^')
plt.scatter(shift_stage_epoch, laptop_f1, c='green', marker='^')
# plt.scatter(shift_stage_epoch, restaurant_acc, c='black', marker='^')
# plt.scatter(shift_stage_epoch, restaurant_f1, c='black', marker='*')
plt.legend(loc='best')
plt.yticks(range(65, 80, 5))
plt.grid(True, linestyle='--', alpha=0.5)
plt.xlabel("Curriculum stage N", fontdict={'size': 16})

plt.savefig("./plot.png")  # 保存图像

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/disk2/jye/ABSA/ABSA-curriculum learning/picture.ipynb 单元格 1 in <cell line: 12>()
#       <a href='vscode-notebook-cell://ssh-remote%2B172.18.31.58/home/disk2/jye/ABSA/ABSA-curriculum%20learning/picture.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # restaurant_acc = [84.335, 84.42, 84.51, 83.93, 85.3]
#      <a href='vscode-notebook-cell://ssh-remote%2B172.18.31.58/home/disk2/jye/ABSA/ABSA-curriculum%20learning/picture.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # restaurant_f1 = [76.03, 76.615, 76.36, 75.855, 78.25]
#      <a href='vscode-notebook-cell://ssh-remote%2B172.18.31.58/home/disk2/jye/ABSA/ABSA-curriculum%20learning/picture.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> plt.plot(shift_stage_epoch, laptop_accuracy, c='green', label="laptop acc")
# ...
